# %%
import requests
from bs4 import BeautifulSoup
page = requests.get("https://stackoverflow.com/questions")
soup = BeautifulSoup(page.text, 'html.parser')

# %%
p=soup.select(".question-summary")
#question its answer and the no of votes and views are extacted one by one from soup
for i in p:
    print(i.select_one('.question-hyperlink').getText())
    print(i.select_one('.excerpt').getText())
    print(i.select_one('.vote-count-post').getText())
    print(i.select_one('.views').getText())
# Out:
# Dinamically add row with Jquery
#
#             I have an application that integrated with barcode scanner, like this:
# I have made a row dynamically with this snippet of code:
#
# <link href="//maxcdn.bootstrapcdn.com/bootstrap/3.3.0/css/bootstrap....
#
# 0
#
#     3 views
#
# Silverstripe 3 filter ArrayList
#
#             How can we filter an ArrayList in Silverstripe 3?
# where getVideosfromCategories() returns a merged ArrayList
# I need something Like:
#
# $this->getVideosfromCategories()->filter('ID:LessThan', $id)-&...
#
# 0
#
#     2 views
#
# Image rotation output is black java
#
#             I am trying to create a method- static int[ ][ ][ ] rotate90(int[ ][ ][ ] image)
# i did manage to rotate the image by the looks of it but its completely black. the code below:
#
#     ...
#     ...
#
# 0
#
#     2 views
#
# Mouse Leave event in Firemonkey XE10.3
#
#             I have a form with a control (myControl) and a child control (myChildControl).
#
# ...

# %%
\
# Out:
# How can I properly use for loop in def? [closed]
#
#             def kolas(lst, n):
#     for i in range(0, len(lst)):
#         e = []
#         x = lst[i] % n
#         e.append(x)
#     return x
# I noticed that for loop doesn't affect in def() - i is only assigned by the ...
#
# -3
#
#     16 views
